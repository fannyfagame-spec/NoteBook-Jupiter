# %% [markdown]
# <a href="https://colab.research.google.com/github/fannyfagame-spec/NoteBook-Jupiter/blob/main/%5BJupyter_Notebooks_Youth%5D_NLP_NLTK%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font size="+3">Module 34 - NLTK-Natural Language ToolKit</font>
#
# In this notebook, we are going to discuss how to use the natural language toolkit to process, analyse and gain insights about natural language.

# %% [markdown]
# ### Import NLTK

# %%
# import warnings to avoid any version warnings etc.
import warnings
warnings.filterwarnings("ignore")

# %%
# import NLTK
import nltk
# A sentence as an example
sent = "I would like to walk more and more to  keep walking all the time improve my health and stay healthy and safe!"
print(sent)
# Out:
# I would like to walk more and more to  keep walking all the time improve my health and stay healthy and safe!

# %% [markdown]
# **<p style="font-family: Arial; font-size:1.4em;color:blue;">Exercise: Sentence input  </p>**

# %%
# Q1. Apply NLTK step-wise for the text input:"I was interested in eating icecream, but it was raining , so I could not eat !"

# %%
send = "I was interested in eating icecream, but it was raining , so I could not eat !"
print(send)
# Out:
# I was interested in eating icecream, but it was raining , so I could not eat !

# %% [markdown]
# ### Tokenization

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# import tokenizer
from nltk import word_tokenize
# A sentence as an example:Divide text into words or sentences
sent = "I would like to walk more and more to  keep walking all the time improve my health and stay healthy and safe!"
print(word_tokenize(sent))
# Out:
# ['I', 'would', 'like', 'to', 'walk', 'more', 'and', 'more', 'to', 'keep', 'walking', 'all', 'the', 'time', 'improve', 'my', 'health', 'and', 'stay', 'healthy', 'and', 'safe', '!']

# %% [markdown]
# **<p style="font-family: Arial; font-size:1.4em;color:blue;">Exercise: Tokenization  </p>**

# %%
# Tokenization:

# %%
from nltk import word_tokenize
print(word_tokenize(send))
# Out:
# ['I', 'was', 'interested', 'in', 'eating', 'icecream', ',', 'but', 'it', 'was', 'raining', ',', 'so', 'I', 'could', 'not', 'eat', '!']

# %% [markdown]
# ### Stop-words

# %%
from nltk import pos_tag
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')

from nltk.corpus import stopwords

token = word_tokenize(send)
stop_words = stopwords.words('english')
cleaned_token = [word for word in token if word not in stop_words]

tagged = pos_tag(cleaned_token)
print(tagged)
# Out:
# [('I', 'PRP'), ('interested', 'VBD'), ('eating', 'VBG'), ('icecream', 'NN'), (',', ','), ('raining', 'VBG'), (',', ','), ('I', 'PRP'), ('could', 'MD'), ('eat', 'VB'), ('!', '.')]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %% [markdown]
# **<p style="font-family: Arial; font-size:1.4em;color:blue;">Exercise: Stop-words  </p>**

# %%
# removing stop words from the text input

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = stopwords.words('english')
token = word_tokenize(send)
cleaned_token = []
for word in token:
    if word not in stop_words:
        cleaned_token.append(word)
print("Unclean:", token)
print("Cleaned:", cleaned_token)
# Out:
# Unclean: ['I', 'was', 'interested', 'in', 'eating', 'icecream', ',', 'but', 'it', 'was', 'raining', ',', 'so', 'I', 'could', 'not', 'eat', '!']
# Cleaned: ['I', 'interested', 'eating', 'icecream', ',', 'raining', ',', 'I', 'could', 'eat', '!']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Convert Text into lower case:

# %%
# converting the text into a common case
lower_sent = sent.lower()
print (lower_sent)
# Out:
# i would like to walk more and more to  keep walking all the time improve my health and stay healthy and safe!

# %% [markdown]
# **<p style="font-family: Arial; font-size:1.4em;color:blue;">Exercise: Common Case  </p>**

# %%
# Convert into lower case:

# %%
lower_send = send.lower()
print(lower_send)
# Out:
# i was interested in eating icecream, but it was raining , so i could not eat !

# %% [markdown]
# ### Lemmatization

# %%
# import the lemmatizer
from nltk.stem import WordNetLemmatizer
stopword = stopwords.words('english')
wordnet_lemmatizer = WordNetLemmatizer()
word_tokens = nltk.word_tokenize(sent)
lemmatized_word = [wordnet_lemmatizer.lemmatize(word) for word in word_tokens]
print (lemmatized_word)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /usr/local/lib/python3.12/dist-packages/nltk/data.py in find(resource_name, paths)
#     578     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579     raise LookupError(resource_not_found)
#     580
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# /tmp/ipykernel_7168/4176798448.py in <cell line: 0>()
#       4 wordnet_lemmatizer = WordNetLemmatizer()
#       5 word_tokens = nltk.word_tokenize(sent)
# ----> 6 lemmatized_word = [wordnet_lemmatizer.lemmatize(word) for word in word_tokens]
#       7 print (lemmatized_word)
#
# /usr/local/lib/python3.12/dist-packages/nltk/stem/wordnet.py in lemmatize(self, word, pos)
#      83         :return: The shortest lemma of `word`, for the given `pos`.
#      84         """
# ---> 85         lemmas = self._morphy(word, pos)
#      86         return min(lemmas, key=len) if lemmas else word
#      87
#
# /usr/local/lib/python3.12/dist-packages/nltk/stem/wordnet.py in _morphy(self, form, pos, check_exceptions)
#      39         from nltk.corpus import wordnet as wn
#      40
# ---> 41         return wn._morphy(form, pos, check_exceptions)
#      42
#      43     def morphy(self, form, pos=None, check_exceptions=True):
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     118             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     119
# --> 120         self.__load()
#     121         # This looks circular, but its not, since __load() changes our
#     122         # __class__ to something new:
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/util.py in __load(self)
#      84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#      88         # Load the corpus.
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/util.py in __load(self)
#      79         else:
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#      83                 try:
#
# /usr/local/lib/python3.12/dist-packages/nltk/data.py in find(resource_name, paths)
#     577     sep = "*" * 70
#     578     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579     raise LookupError(resource_not_found)
#     580
#     581
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# **<p style="font-family: Arial; font-size:1.4em;color:blue;">Exercise: Lemmatization  </p>**

# %%
# lemmatizer

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

wordnet_lemmatizer = WordNetLemmatizer()
word_tokens = nltk.word_tokenize(send)
lemmatized_word = [wordnet_lemmatizer.lemmatize(word) for word in word_tokens]
print(lemmatized_word)

# %% [markdown]
# ### Word Frequency

# %%
# Counting the frequency of words in the sentence
from nltk import FreqDist
word = nltk.word_tokenize(sent.lower())
freq = FreqDist(word)
print (freq.most_common(5))
# Out:
# [('and', 3), ('to', 2), ('more', 2), ('i', 1), ('would', 1)]

# %% [markdown]
# **<p style="font-family: Arial; font-size:1.4em;color:blue;">Exercise: Word Frequency  </p>**

# %%
# Counting the frequency of words in the sentence

# %%
from nltk import FreqDist
word = nltk.word_tokenize(send.lower())
freq = FreqDist(word)
print(freq.most_common(5))
# Out:
# [('i', 2), ('was', 2), (',', 2), ('interested', 1), ('in', 1)]

# %% [markdown]
# ### Tagging Parts-of-speech

# %%
# Attaching Parts- of-speech to each of the words in the sentence
from nltk import pos_tag
token = word_tokenize(sent)
tagged = pos_tag(cleaned_token)
print(tagged)
# Out:
# [('I', 'PRP'), ('interested', 'VBD'), ('eating', 'VBG'), ('icecream', 'NN'), (',', ','), ('raining', 'VBG'), (',', ','), ('I', 'PRP'), ('could', 'MD'), ('eat', 'VB'), ('!', '.')]

# %% [markdown]
# **<p style="font-family: Arial; font-size:1.4em;color:blue;">Exercise: Parts of speech  </p>**

# %%
# Attaching Parts- of-speech to each of the words in the sentence

# %%
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger_eng')

token = word_tokenize(send)

# bikin cleaned_token dulu
stop_words = stopwords.words('english')
cleaned_token = [word for word in token if word not in stop_words]

tagged = pos_tag(cleaned_token)
print(tagged)
# Out:
# [('I', 'PRP'), ('interested', 'VBD'), ('eating', 'VBG'), ('icecream', 'NN'), (',', ','), ('raining', 'VBG'), (',', ','), ('I', 'PRP'), ('could', 'MD'), ('eat', 'VB'), ('!', '.')]
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
